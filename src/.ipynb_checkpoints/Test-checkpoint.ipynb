# %%
import json
import urllib.request
import pandas as pd
import os
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt

from keras.layers import Dense
from keras.models import Sequential
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
def lookup_latlng(city_df, api_key=''):
    """
    Convert address name to latitude and longitude
    @ param city_df: name is city name, subordinary is prefecture name (https://datahub.io/core/world-cities)
    @ param api_key: APY Key for Google Map API
    @ retrun city_df: lat, lng added city data
    """
    #city_df = city_df.head()
    city_l = city_df['name'] + ',' + city_df['subcountry']
    lat = []
    lng = []
    ggl_url = "https://maps.googleapis.com/maps/api/geocode/json?address="
    api_key = "AIzaSyCrUUNVdkMhCcQ17u-WBjgDTQz2wDi5ng4"
    # GEOCODING Lookup, by Google Maps API
    for w in city_l:
        print(w)
        url = ggl_url + w + "&key=" + api_key
        response = urllib.request.urlopen(url)
        content = json.loads(response.read().decode('utf8'))
        if content['status'] == 'OK':
            lat_tmp = content['results'][0]['geometry']['location']['lat']
            lng_tmp = content['results'][0]['geometry']['location']['lng']
        else:
            lat_tmp = 0
            lng_tmp = 0
        lat.append(lat_tmp)
        lng.append(lng_tmp)

    city_df['lat'] = lat
    city_df['lng'] = lng
    city_df = city_df[city_df.lat != 0]
    print(city_df.head())
    pd.DataFrame.to_csv(city_df, "../data/CityData_latlng.csv")
    return city_df

# %%
df = pd.read_csv('../data/world-cities_csv.csv')
df_jp = df[df['country'] == "Japan"]
df_jp.head()
# Out:
#          name country subcountry  geonameid
# 12109  Shingu   Japan   Wakayama    1847947
# 12110  Atsugi   Japan   Kanagawa    1847963
# 12111  Akashi   Japan      Hyogo    1847966
# 12112   Zushi   Japan   Kanagawa    1847968
# 12113    Zama   Japan   Kanagawa    1848004

# %%
flg_city_df = lookup_latlng(df_jp, '')
# Out:
# Shingu,Wakayama
# Atsugi,Kanagawa
# Akashi,Hyogo
# Zushi,Kanagawa
# Zama,Kanagawa
# Yuza,Yamagata
# Gero,Gifu
# Yukuhashi,Fukuoka
# Yuki,Ibaraki
# Yugawara,Kanagawa
# Yoshikawa,Saitama
# Yoshii,Gunma
# Yoshida-kasugacho,Niigata
# Yorii,Saitama
# Yono,Saitama
# Yonago,Tottori
# Yokosuka,Kanagawa
# Yokohama,Kanagawa
# Yokkaichi,Mie
# Youkaichi,Shiga
# Yawata,Kyoto
# Yatsushiro,Kumamoto
# Yatsuomachi-higashikumisaka,Toyama
# Yasugicho,Shimane
# Yashiro,Hyogo
# Yashio-shi,Saitama
# Yao,osaka
# Yanai,Yamaguchi
# Yanagawa,Fukuoka
# Yamazakicho-nakabirose,Hyogo
# Yamaguchi,Yamaguchi
# Yamaga,Kumamoto
# Yaizu,Shizuoka
# Yaita,Tochigi
# Wakimachi,Tokushima
# Utsunomiya,Tochigi
# Uto,Kumamoto
# Usuki,Oita
# Ushibuka,Kumamoto
# Ureshinomachi-shimojuku,Saga
# Urayasu,Tokyo
# Uozu,Toyama
# Umi,Fukuoka
# Ujiie,Tochigi
# Uji,Kyoto
# Uenohara,Yamanashi
# Ueno-ebisumachi,Mie
# Ueki,Kumamoto
# Ueda,Nagano
# Ube,Yamaguchi
# Tsuyama,Okayama
# Tsushima,Aichi
# Tsurusaki,Oita
# Tsuruoka,Yamagata
# Tsurugi-asahimachi,Ishikawa
# Tsuruga,Fukui
# Tsuma,Miyazaki
# Tsukumiura,Oita
# Tsukawaki,Oita
# Tsubata,Ishikawa
# Tsubame,Niigata
# Tsu,Mie
# Toyota,Aichi
# Toyoshina,Nagano
# Toyooka,Hyogo
# Toyonaka,osaka
# Toyokawa,Aichi
# Toyohashi,Aichi
# Toyohama,Aichi
# Toyama,Toyama
# Tottori,Tottori
# Tosu,Saga
# Tonosho,Kagawa
# Tondabayashicho,osaka
# Tomioka,Gunma
# Tomigusuku,Okinawa
# Tokyo,Tokyo
# Tokuyama,Yamaguchi
# Tokushima,Tokushima
# Tokorozawa,Saitama
# Tokoname,Aichi
# Toki,Gifu
# Tokamachi,Niigata
# Togitsu,Nagasaki
# Tochio-honcho,Niigata
# Tochigi,Tochigi
# Toba,Mie
# Tenri,Nara
# Tenno,Akita
# Tawaramoto,Nara
# Tatsuno,Nagano
# Tatsunocho-tominaga,Hyogo
# Tateyama,Chiba
# Tatebayashi,Gunma
# Tarumizu,Kagoshima
# Tarui,Gifu
# Tanushimarumachi-toyoki,Fukuoka
# Tanuma,Tochigi
# Nishi-Tokyo-shi,Tokyo
# Tanashicho,Tokyo
# Tanabe,Kyoto
# Tanabe,Wakayama
# Tamano,Okayama
# Tamana,Kumamoto
# Tamamura,Gunma
# Taketoyo,Aichi
# Takeocho-takeo,Saga
# Takehara,Hiroshima
# Takefu,Fukui
# Takedamachi,Oita
# Takayama,Gifu
# Takatsuki,osaka
# Takasaki,Gunma
# Takarazuka,Hyogo
# Takaoka,Toyama
# Takanabe,Miyazaki
# Takamatsu,Kagawa
# Takaishi,osaka
# Takahashi,Okayama
# Takahama,Aichi
# Bungo-Takada-shi,Oita
# Tajimi,Gifu
# Tahara,Aichi
# Tagawa,Fukuoka
# Tadotsu,Kagawa
# Suzuka,Mie
# Suzaka,Nagano
# Suwa,Nagano
# Susaki,Kochi
# Sumoto,Hyogo
# Sukumo,Kochi
# Suita,osaka
# Suibara,Niigata
# Sugito,Saitama
# Sueyoshicho-ninokata,Kagoshima
# Soka,Saitama
# Soja,Okayama
# Sobue,Aichi
# Shobu,Saitama
# Shobara,Hiroshima
# Shizuoka,Shizuoka
# Shirone,Niigata
# Shiraoka,Saitama
# Shirahamacho-usazakiminami,Hyogo
# Shiozawa,Niigata
# Shiojiri,Nagano
# Shinshiro,Aichi
# Shinichi,Hiroshima
# Shingu,Fukuoka
# Shimonoseki,Yamaguchi
# Shimodate,Ibaraki
# Shimoda,Shizuoka
# Minato,Wakayama
# Nishishinminato,Toyama
# Shimada,Shizuoka
# Shimabara,Nagasaki
# Shiki,Saitama
# Shido,Kagawa
# Shibushi,Kagoshima
# Shibukawa,Gunma
# Shibata,Niigata
# Seto,Aichi
# Setakamachi-takayanagi,Fukuoka
# Satsumasendai,Kagoshima
# Satte,Saitama
# Sasebo,Nagasaki
# Sasayama,Hyogo
# Sasaguri,Fukuoka
# Sano,Tochigi
# Sanjo,Niigata
# Sandacho,Hyogo
# Sakurai,Nara
# Saku,Nagano
# Sakata,Yamagata
# Sakaiminato,Shimane
# Sakaidecho,Kagawa
# Sakai-nakajima,Gunma
# Sakai,Ibaraki
# Sakai,osaka
# Sakado,Saitama
# Saiki,Oita
# Sagara,Shizuoka
# Saga,Saga
# Sabae,Fukui
# Ryuo,Yamanashi
# Ryotsu-minato,Niigata
# Ozu,Kumamoto
# Oyama,Tochigi
# Oyama,Shizuoka
# Owase,Mie
# Otsuki,Yamanashi
# Otsu,Shiga
# Otake,Yamaguchi
# Ota,Gunma
# Osaka,osaka
# Onomichi,Hiroshima
# Onoda,Yamaguchi
# Ono,Fukui
# Ono,Hyogo
# Ono-hara,Hiroshima
# Omuta,Fukuoka
# Omura,Nagasaki
# Ome,Tokyo
# Omamacho-omama,Gunma
# Omachi,Nagano
# Okuchi-shinohara,Kagoshima
# Okegawa,Saitama
# Okazaki,Aichi
# Okayama,Okayama
# Okaya,Nagano
# Okawa,Saga
# Ojiya,Niigata
# Oita,Oita
# Oiso,Kanagawa
# Oi,Saitama
# Ogori-shimogo,Yamaguchi
# Ogawa,Saitama
# Ogaki,Gifu
# Odawara,Kanagawa
# Odacho-oda,Shimane
# Obu,Aichi
# Obita,Nagasaki
# Obama,Fukui
# Nyuzen,Toyama
# Numazu,Shizuoka
# Numata,Gunma
# Nonoichi,Ishikawa
# Nogata,Fukuoka
# Noda,Chiba
# Nobeoka,Miyazaki
# Nishiwaki,Hyogo
# Nishio,Aichi
# Nishinoomote,Kagoshima
# Nishinomiya-hama,Hyogo
# Nirasaki,Yamanashi
# Ninomiya,Kanagawa
# Nikko,Tochigi
# Niitsu-honcho,Niigata
# Niimi,Okayama
# Niihama,Ehime
# Niigata,Niigata
# Nichinan,Miyazaki
# Naze,Kagoshima
# Narutocho-mitsuishi,Tokushima
# Nara-shi,Nara
# Nanao,Ishikawa
# Namerikawa,Toyama
# Nakatsugawa,Gifu
# Nakatsu,Fukuoka
# Nakanojomachi,Gunma
# Nakano,Nagano
# Nakamura,Kochi
# Nakama,Fukuoka
# Naha,Okinawa
# Nagoya,Aichi
# Nago,Okinawa
# Nagasaki,Nagasaki
# Nagareyama,Chiba
# Nagaoka,Niigata
# Nagano,Nagano
# Nagahama,Shiga
# Nabari,Mie
# Musashino,Tokyo
# Muroto-misakicho,Kochi
# Muramatsu,Niigata
# Murakami,Niigata
# Muko,Kyoto
# Muikamachi,Niigata
# Morohongo,Saitama
# Moriyama,Shiga
# Moriguchi,osaka
# Mori,Shizuoka
# Mizunami,Gifu
# Miyoshi,Hiroshima
# Miyazu,Kyoto
# Miyazaki,Miyazaki
# Miyakonojo,Miyazaki
# Miyata,Fukuoka
# Mitsuke,Niigata
# Mitsukaido,Ibaraki
# Mitake,Gifu
# Mitaka-shi,Tokyo
# Mishima,Shizuoka
# Mino,osaka
# Mino,Gifu
# Minamirinkan,Kanagawa
# Minamata,Kumamoto
# Minakuchicho-matoba,Shiga
# Mikuni,Fukui
# Miki,Hyogo
# Mihara,Hiroshima
# Mibu,Tochigi
# Menuma,Saitama
# Matsuto,Ishikawa
# Matsumoto,Nagano
# Matsue,Shimane
# Matsudo,Chiba
# Matsubase,Kumamoto
# Matsubara,osaka
# Masuda,Shimane
# Maruoka,Fukui
# Kamimaruko,Nagano
# Marugame,Kagawa
# Makurazaki,Kagoshima
# Maki,Niigata
# Maizuru,Kyoto
# Maebashi,Gunma
# Maebaru-chuo,Fukuoka
# Machida,Tokyo
# Kyoto,Kyoto
# Kushikino,Kagoshima
# Kusatsu,Shiga
# Kurume,Fukuoka
# Kuroda,Aichi
# Kurihashi,Saitama
# Kure,Hiroshima
# Kurayoshi,Tottori
# Kurashiki,Okayama
# Kumamoto,Kumamoto
# Kumagaya,Saitama
# Kukichuo,Saitama
# Kudamatsu,Yamaguchi
# Kozakai-cho,Aichi
# Koshigaya,Saitama
# Kosai-shi,Shizuoka
# Konosu,Saitama
# Konan,Aichi
# Komoro,Nagano
# Komono,Mie
# Komatsushimacho,Tokushima
# Komatsu,Ishikawa
# Komaki,Aichi
# Kokubunji,Tokyo
# Kokubu-matsuki,Kagoshima
# Koga,Ibaraki
# Koga,Fukuoka
# Kofu,Yamanashi
# Kodamacho-kodamaminami,Saitama
# Kochi,Kochi
# Kobe,Hyogo
# Kobayashi,Miyazaki
# Kitsuki,Oita
# Kitakyushu,Fukuoka
# Kitakata,Fukushima
# Kitahama,Shiga
# Kishiwada,osaka
# Kisarazu,Chiba
# Kisai,Saitama
# Kiryu,Gunma
# Kikuchi,Kumamoto
# Kazo,Saitama
# Kawasaki,Kanagawa
# Kawasaki,Fukuoka
# Kawanishi,Hyogo
# Kawaguchi,Saitama
# Kawagoe,Saitama
# Katsuyama,Fukui
# Kasukabe,Saitama
# Kasugai,Aichi
# Kashiwazaki,Niigata
# Kashiwa,Chiba
# Kashima,Saga
# Kashihara-shi,Nara
# Kashihara,osaka
# Kaseda-shirakame,Kagoshima
# Kasaoka,Okayama
# Kasamatsucho,Gifu
# Kariya,Aichi
# Karatsu,Saga
# Kanzakimachi-kanzaki,Saga
# Kanuma,Tochigi
# Kanoya,Kagoshima
# Kanonjicho,Kagawa
# Kannabecho-yahiro,Hiroshima
# Kanie,Aichi
# Kanekomachi,Gunma
# Kanda,Fukuoka
# Kanazawa,Ishikawa
# Kanaya,Shizuoka
# Kamojimacho-jogejima,Tokushima
# Kamogatacho-kamogata,Okayama
# Kamo,Niigata
# Kamirenjaku,Tokyo
# Kaminokawa,Tochigi
# Kamiichi,Toyama
# Kameyama,Mie
# Kameoka,Kyoto
# Kameda-honcho,Niigata
# Kamakura,Kanagawa
# Kakogawacho-honmachi,Hyogo
# Kakegawa,Shizuoka
# Kakamigahara,Gifu
# Kashima-shi,Ibaraki
# Kajiki,Kagoshima
# Kaizuka,osaka
# Kainan,Wakayama
# Kagoshima,Kagoshima
# Kadoma,osaka
# Izumo,Shimane
# Izumiotsu,osaka
# Izumi,osaka
# Izumi,Kagoshima
# Iwatsuki,Saitama
# Iwata,Shizuoka
# Iwakura,Aichi
# Iwakuni,Yamaguchi
# Iwai,Ibaraki
# Iwade,Wakayama
# Itsukaichi,Tokyo
# Itoman,Okinawa
# Itoigawa,Niigata
# Ito,Shizuoka
# Itami,Hyogo
# Ishiki,Aichi
# Ishikawa,Okinawa
# Ishii,Tokushima
# Ishige,Ibaraki
# Ishigaki,Okinawa
# Isesaki,Gunma
# Isehara,Kanagawa
# Ise,Mie
# Isawa,Yamanashi
# Isahaya,Nagasaki
# Inuyama,Gifu
# Ino,Kochi
# Innoshima,Hiroshima
# Inazawa,Aichi
# Ina,Nagano
# Imaricho-ko,Saga
# Imaichi,Tochigi
# Ikoma,Nara
# Ikeda,osaka
# Ikedacho,Tokushima
# Ijuin,Kagoshima
# Iizuka,Fukuoka
# Iiyama,Nagano
# Iida,Nagano
# Ichinomiya,Aichi
# Ibusuki,Kagoshima
# Ibaraki,osaka
# Ibara,Okayama
# Hotaka,Nagano
# Honjo,Saitama
# Hondo,Kumamoto
# Hofu,Yamaguchi
# Hitoyoshi,Kumamoto
# Hita,Oita
# Hisai-motomachi,Mie
# Hiroshima,Hiroshima
# Hiratsuka,Kanagawa
# Hiratacho,Shimane
# Hirara,Okinawa
# Hirakata,osaka
# Hirado,Nagasaki
# Hino,Tokyo
# Hino,Shiga
# Himimachi,Toyama
# Himeji,Hyogo
# Hikone,Shiga
# Hiji,Oita
# Hekinan,Aichi
# Hayama,Kanagawa
# Hatsukaichi,Hiroshima
# Hatogaya-honcho,Saitama
# Hashimoto,Wakayama
# Hanyu,Saitama
# Hanno,Saitama
# Handa,Aichi
# Hamanoichi,Kagoshima
# Hamamatsu,Shizuoka
# Hamakita,Shizuoka
# Hamada,Shimane
# Hakui,Ishikawa
# Haibara-akanedai,Nara
# Hagi,Yamaguchi
# Katsuren-haebaru,Okinawa
# Hadano,Kanagawa
# Hachioji,Tokyo
# omihachiman,Shiga
# Gyoda,Saitama
# Gushikawa,Okinawa
# Gotsucho,Shimane
# Gotenba,Shizuoka
# Gosen,Niigata
# Gose,Nara
# Gojo,Nara
# Godo,Gifu
# Gobo,Wakayama
# Ginowan,Okinawa
# Gifu-shi,Gifu
# Gamagori,Aichi
# Futtsu,Chiba
# Honcho,Chiba
# Fukuyama,Hiroshima
# Fukuroi,Shizuoka
# Fukura,Hyogo
# Fukuoka,Fukuoka
# Fukumitsu,Toyama
# Nishifukuma,Fukuoka
# Fukui-shi,Fukui
# Fukuecho,Nagasaki
# Fukuchiyama,Kyoto
# Fukiage-fujimi,Saitama
# Fukayacho,Saitama
# Fujisawa,Kanagawa
# Fujioka,Tochigi
# Fujioka,Gunma
# Fujinomiya,Shizuoka
# Fujieda,Shizuoka
# Fuji,Shizuoka
# Fuchucho,Hiroshima
# Enzan,Yamanashi
# Daitocho,osaka
# Chofugaoka,Tokyo
# Chiryu,Aichi
# Chino,Nagano
# Chikushino-shi,Fukuoka
# Chigasaki,Kanagawa
# Chichibu,Saitama
# Chatan,Okinawa
# Beppu,Oita
# Ayabe,Kyoto
# Atami,Shizuoka
# Ashiya,Hyogo
# Ashikaga,Tochigi
# Arai,Niigata
# Annaka,Gunma
# Anjo,Aichi
# Anan,Tokushima
# Amagi,Fukuoka
# Amagasaki,Hyogo
# Akune,Kagoshima
# Kariya,Hyogo
# Aki,Kochi
# Aioi,Hyogo
# Ageoshimo,Saitama
# Okinawa,Okinawa
# Kushima,Miyazaki
# Hikari,Yamaguchi
# Nagato,Yamaguchi
# Hasuda,Saitama
# Kamifukuoka,Saitama
# Sayama,Saitama
# Fussa,Tokyo
# Asaka,Saitama
# Wako,Saitama
# Shimotoda,Saitama
# Kimitsu,Chiba
# Miura,Kanagawa
# Wakayama,Wakayama
# Iyo,Ehime
# Uwajima,Ehime
# Saijo,Ehime
# ozu,Ehime
# Matsuyama,Ehime
# Masaki-cho,Ehime
# Kawanoecho,Ehime
# Hojo,Ehime
# Yuzawa,Akita
# Yotsukaido,Chiba
# Yonezawa,Yamagata
# Yokotemachi,Akita
# Yokaichiba,Chiba
# Yanagawamachi-saiwaicho,Fukushima
# Yamoto,Miyagi
# Yamagata,Yamagata
# Yamada,Iwate
# Yachimata,Chiba
# Watari,Miyagi
# Wakuya,Miyagi
# Ushiku,Ibaraki
# Tsukuba,Ibaraki
# Toride,Ibaraki
# Tono,Iwate
# Tomobe,Ibaraki
# Tomiya,Miyagi
# Togane,Chiba
# Tendo,Yamagata
# Takahata,Yamagata
# Takahagi,Ibaraki
# Sukagawa,Fukushima
# Shizukuishi,Iwate
# Shisui,Chiba
# Shiroishi,Miyagi
# Shiroi,Chiba
# Shiogama,Miyagi
# Shinjo,Yamagata
# Sendai,Miyagi
# Sawara,Chiba
# Sakura,Chiba
# Sagae,Yamagata
# Ryugasaki,Ibaraki
# Rifu,Miyagi
# otsuchi,Iwate
# otawara,Tochigi
# omiya,Ibaraki
# Omigawa,Chiba
# omagari,Akita
# Okunoya,Ibaraki
# okawara,Miyagi
# ohara,Chiba
# ofunato,Iwate
# Obanazawa,Yamagata
# oarai,Ibaraki
# oami,Chiba
# Nihommatsu,Fukushima
# Naruto,Chiba
# Narita,Chiba
# Namie,Fukushima
# Naka,Ibaraki
# Nagai,Yamagata
# Motomiya,Fukushima
# Motegi,Tochigi
# Moriya,Ibaraki
# Morioka,Iwate
# Mooka,Tochigi
# Mobara,Chiba
# Mizusawa,Iwate
# Miyako,Iwate
# Mito,Ibaraki
# Miharu,Fukushima
# Matsushima,Miyagi
# Mashiko,Tochigi
# Marumori,Miyagi
# Makabe,Ibaraki
# Kuroiso,Tochigi
# Koriyama,Fukushima
# Kogota,Miyagi
# Kitakami,Iwate
# Kitaibaraki,Ibaraki
# Kamogawa,Chiba
# Katsuura,Chiba
# Katsuta,Ibaraki
# Katori-shi,Chiba
# Kasama,Ibaraki
# Karasuyama,Tochigi
# Kaminoyama,Yamagata
# Kamaishi,Iwate
# Kakuda,Miyagi
# Iwase,Ibaraki
# Iwanuma,Miyagi
# Iwaki,Fukushima
# Itako,Ibaraki
# Ishioka,Ibaraki
# Ishinomaki,Miyagi
# Ishikawa,Fukushima
# Inawashiro,Fukushima
# Ichinoseki,Iwate
# Ichihara,Chiba
# Hobaramachi,Fukushima
# Hitachi,Ibaraki
# Higashine,Yamagata
# Hasaki,Chiba
# Hanamaki,Iwate
# Furukawa,Miyagi
# Funehikimachi-funehiki,Fukushima
# Funaishikawa,Ibaraki
# Fukushima,Fukushima
# Fujishiro,Ibaraki
# Edosaki,Ibaraki
# Daigo,Ibaraki
# Chiba,Chiba
# Asahi,Chiba
# Ami,Ibaraki
# Akita,Akita
# Abiko,Chiba
# Akitashi,Akita
# Bihoro,Hokkaido
# Wakkanai,Hokkaido
# Tomakomai,Hokkaido
# Tobetsu,Hokkaido
# Mutsu,Aomori
# Takikawa,Hokkaido
# Takanosu,Akita
# Sunagawa,Hokkaido
# Shizunai-furukawacho,Hokkaido
# Shiraoi,Hokkaido
# Shimo-furano,Hokkaido
# Shibetsu,Hokkaido
# Sapporo,Hokkaido
# Rumoi,Hokkaido
# Otofuke,Hokkaido
# Otaru,Hokkaido
# odate,Akita
# Obihiro,Hokkaido
# Noshiro,Akita
# Nemuro,Hokkaido
# Nayoro,Hokkaido
# Nanae,Hokkaido
# Namioka,Aomori
# Muroran,Hokkaido
# Mombetsu,Hokkaido
# Misawa,Aomori
# Yoichi,Hokkaido
# Makubetsu,Hokkaido
# Kushiro,Hokkaido
# Kuroishi,Aomori
# Shimokizukuri,Aomori
# Kitami,Hokkaido
# Kamiiso,Hokkaido
# Iwanai,Hokkaido
# Iwamizawa,Hokkaido
# Ishikari,Hokkaido
# Ichinohe,Iwate
# Kitahiroshima,Hokkaido
# Hirosaki,Aomori
# Hanawa,Akita
# Hakodate,Hokkaido
# Hachinohe,Aomori
# Fukagawa,Hokkaido
# Ebetsu,Hokkaido
# Date,Hokkaido
# Chitose,Hokkaido
# Bibai,Hokkaido
# Ashibetsu,Hokkaido
# Asahikawa,Hokkaido
# Aomorishi,Aomori
# Abashiri,Hokkaido
# Goshogawara,Aomori
# Aso,Kumamoto
# Nanto-shi,Toyama
# Kawage,Mie
# Neyagawa,osaka
# Hitachi-Naka,Ibaraki
# Inashiki,Ibaraki
# onojo,Fukuoka
# Minokamo,Gifu
# Gujo,Gifu
# Joetsu,Niigata
# Saitama,Saitama
# Higashimurayama-shi,Tokyo
# Fujikawaguchiko,Yamanashi
# Dazaifu,Fukuoka
# Kamigyo-ku,Kyoto
# Buzen,Fukuoka
# Sendai,Miyagi
#          name country subcountry  geonameid        lat         lng
# 12109  Shingu   Japan   Wakayama    1847947  33.724105  135.992411
# 12110  Atsugi   Japan   Kanagawa    1847963  35.443082  139.362489
# 12111  Akashi   Japan      Hyogo    1847966  34.643107  134.997179
# 12112   Zushi   Japan   Kanagawa    1847968  35.295606  139.580423
# 12113    Zama   Japan   Kanagawa    1848004  35.488587  139.407673
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/ipykernel/__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/ipykernel/__main__.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def big_city_flagger(city_df, flg_pass='../data/BigCityList.csv'):
    """
    Add flag of big city
    @ param city_df: lat, lng added city data
    @ return city_df: city data having big city flag
    """
    #flg_city = pd.read_csv(flg_pass)['big_city']
    flg_city_l = ['Tokyo', 'Kyoto', 'Osaka', 'Nagoya', 'Yokohama', 'Kobe', 'Kitakyushu', 'Kawasaki', 'Fukuoka',
                  'Hiroshima', 'Sendai', 'Chiba', 'Saitama', 'Shizuoka', 'Sakai', 'Niigata', 'Hamamatsu', 'Okayama',
                  'Sagamihara', 'Kumamoto']
    flg_l = []
    cnt = 0
    for city in city_df['name']:
        if city in flg_city_l:
            flg_l.append(1)
            cnt += cnt
        else:
            flg_l.append(0)
    city_df['flg'] = flg_l
    print(cnt == len(flg_city_l)) # 未対応：Sakai, Kawasakiが複数市でヒット。Sendaiはデータに重複（データ重複は後工程的に問題ない）
    return city_df

# %%
flg_latlng_city = big_city_flagger(flg_city_df)
# Out:
# False
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
flg_latlng_city[flg_latlng_city.flg == 1]
# Out:
#              name country subcountry  geonameid        lat         lng  flg
# 12126    Yokohama   Japan   Kanagawa    1848354  35.443708  139.638026    1
# 12185       Tokyo   Japan      Tokyo    1850147  35.709026  139.731992    1
# 12249    Shizuoka   Japan   Shizuoka    1851717  34.975562  138.382760    1
# 12286       Sakai   Japan    Ibaraki    1853193  36.108426  139.794961    1
# 12287       Sakai   Japan      osaka    1853195  34.573262  135.482998    1
# 12303       Osaka   Japan      osaka    1853909  34.693738  135.502165    1
# 12317     Okayama   Japan    Okayama    1854383  34.655146  133.919502    1
# 12349     Niigata   Japan    Niigata    1855431  37.916192  139.036413    1
# 12363      Nagoya   Japan      Aichi    1856057  35.181446  136.906398    1
# 12418       Kyoto   Japan      Kyoto    1857910  35.011636  135.768029    1
# 12427    Kumamoto   Japan   Kumamoto    1858421  32.803100  130.707891    1
# 12448        Kobe   Japan      Hyogo    1859171  34.690083  135.195511    1
# 12451  Kitakyushu   Japan    Fukuoka    1859307  33.883409  130.875216    1
# 12460    Kawasaki   Japan   Kanagawa    1859642  35.529820  139.702404    1
# 12461    Kawasaki   Japan    Fukuoka    1859647  33.599940  130.814937    1
# 12557   Hiroshima   Japan  Hiroshima    1862415  34.385203  132.455293    1
# 12578   Hamamatsu   Japan   Shizuoka    1863289  34.710834  137.726126    1
# 12605     Fukuoka   Japan    Fukuoka    1863967  33.590355  130.401715    1
# 12696      Sendai   Japan     Miyagi    2111149  38.268215  140.869356    1
# 12770       Chiba   Japan      Chiba    2113015  35.607267  140.106291    1
# 12838     Saitama   Japan    Saitama    6940394  35.861729  139.645482    1
# 12844      Sendai   Japan     Miyagi    8555918  38.268215  140.869356    1

# %%
def get_ggl_image(city_df, zoom=16, size=640, img_dir='../imgs/'):
    """
    Get google satellite image via Google Map API
    @ param city_df: df including city name and latlng
    @ param zoom: zoom level
    @ param size: image size
    @ param img_dir: directory pass for image folder
    """
    # Map Configue
    lat = city_df['lat']
    lng = city_df['lng']
    city_name = city_df['flg'].astype(str) + '_' + city_df['name'] + '_' + city_df['subcountry']
    im_type = "satellite"
    api_key = "AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M" # <- confidential
    ggl_url = "https://maps.googleapis.com/maps/api/staticmap"
    cnt = 0
    # Scraping google map
    for i in city_name.index:
        # Issue the image url
        img_url = ggl_url + "?center=" + str(lat[i]) + "," + str(lng[i]) + "&zoom=" + str(zoom) + "&size=" + str(size) + "x" + str(size) + "&maptype=" + im_type + "&key=" + api_key
        print(city_name[i])
        print(img_url)
        # Save images
        urllib.request.urlretrieve(img_url, img_dir + city_name[i] + ".jpg")
        cnt += 1
    print(str(cnt) + " images are stored at " + img_dir)

# %%
def get_ggl_image_sep(city_df, zoom=16, size=640, img_dir='../imgs/'):
    """
    Get google satellite image via Google Map API
    @ param city_df: df including city name and latlng
    @ param zoom: zoom level
    @ param size: image size
    @ param img_dir: directory pass for image folder
    """
    # Map Configue
    lat = city_df['lat']
    lng = city_df['lng']
    city_name = city_df['flg'].astype(str) + '_' + city_df['name'] + '_' + city_df['subcountry']
    im_type = "satellite"
    api_key = "AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M" # <- confidential
    ggl_url = "https://maps.googleapis.com/maps/api/staticmap"
    cnt = 0
    # Scraping google map
    for i in city_name.index:
        # Issue the image url
        img_url = ggl_url + "?center=" + str(lat[i]) + "," + str(lng[i]) + "&zoom=" + str(zoom) + "&size=" + str(size) + "x" + str(size) + "&maptype=" + im_type + "&key=" + api_key
        print(city_name[i])
        print(img_url)
        # Save images
        if city_name[i][0] == '0':
            urllib.request.urlretrieve(img_url + 'bigCity/', img_dir + city_name[i] + ".jpg")
        else:
            urllib.request.urlretrieve(img_url + 'normCity/', img_dir + city_name[i] + ".jpg")
        cnt += 1
    print(str(cnt) + " images are stored at " + img_dir)

# %%
get_ggl_image(flg_latlng_city)
# Out:
# 0_Shingu_Wakayama
# https://maps.googleapis.com/maps/api/staticmap?center=33.7241048,135.9924107&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Atsugi_Kanagawa
# https://maps.googleapis.com/maps/api/staticmap?center=35.4430818,139.3624889&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Akashi_Hyogo
# https://maps.googleapis.com/maps/api/staticmap?center=34.6431066,134.9971787&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Zushi_Kanagawa
# https://maps.googleapis.com/maps/api/staticmap?center=35.2956059,139.5804228&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Zama_Kanagawa
# https://maps.googleapis.com/maps/api/staticmap?center=35.4885872,139.4076731&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yuza_Yamagata
# https://maps.googleapis.com/maps/api/staticmap?center=39.0146158,139.9073521&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Gero_Gifu
# https://maps.googleapis.com/maps/api/staticmap?center=35.8058817,137.2441002&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yukuhashi_Fukuoka
# https://maps.googleapis.com/maps/api/staticmap?center=33.7287727,130.982967&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yuki_Ibaraki
# https://maps.googleapis.com/maps/api/staticmap?center=36.3054165,139.8766414&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yugawara_Kanagawa
# https://maps.googleapis.com/maps/api/staticmap?center=35.1479639,139.1083167&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yoshikawa_Saitama
# https://maps.googleapis.com/maps/api/staticmap?center=35.8911519,139.841375&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yoshii_Gunma
# https://maps.googleapis.com/maps/api/staticmap?center=36.2559553,138.9845412&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yoshida-kasugacho_Niigata
# https://maps.googleapis.com/maps/api/staticmap?center=37.6837922,138.8825459&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yorii_Saitama
# https://maps.googleapis.com/maps/api/staticmap?center=36.1183484,139.1930115&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yono_Saitama
# https://maps.googleapis.com/maps/api/staticmap?center=35.898488,139.630904&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yonago_Tottori
# https://maps.googleapis.com/maps/api/staticmap?center=35.4280717,133.3309447&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yokosuka_Kanagawa
# https://maps.googleapis.com/maps/api/staticmap?center=35.2813412,139.6722005&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 1_Yokohama_Kanagawa
# https://maps.googleapis.com/maps/api/staticmap?center=35.4437078,139.6380256&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yokkaichi_Mie
# https://maps.googleapis.com/maps/api/staticmap?center=34.9651567,136.6244847&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Youkaichi_Shiga
# https://maps.googleapis.com/maps/api/staticmap?center=35.1129917,136.1996682&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yawata_Kyoto
# https://maps.googleapis.com/maps/api/staticmap?center=34.8755551,135.7076209&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yatsushiro_Kumamoto
# https://maps.googleapis.com/maps/api/staticmap?center=32.5083871,130.6020961&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yatsuomachi-higashikumisaka_Toyama
# https://maps.googleapis.com/maps/api/staticmap?center=36.567208,137.1294217&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yasugicho_Shimane
# https://maps.googleapis.com/maps/api/staticmap?center=35.3561081,133.2779384&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yashiro_Hyogo
# https://maps.googleapis.com/maps/api/staticmap?center=34.9174953,134.968804&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yashio-shi_Saitama
# https://maps.googleapis.com/maps/api/staticmap?center=35.822536,139.8391748&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yao_osaka
# https://maps.googleapis.com/maps/api/staticmap?center=34.6268635,135.6009775&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yanai_Yamaguchi
# https://maps.googleapis.com/maps/api/staticmap?center=33.9638333,132.1015969&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yanagawa_Fukuoka
# https://maps.googleapis.com/maps/api/staticmap?center=33.1630889,130.4057531&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yamaguchi_Yamaguchi
# https://maps.googleapis.com/maps/api/staticmap?center=34.178496,131.4737269&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yamaga_Kumamoto
# https://maps.googleapis.com/maps/api/staticmap?center=33.0175778,130.6913646&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yaizu_Shizuoka
# https://maps.googleapis.com/maps/api/staticmap?center=34.8669202,138.3231893&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Yaita_Tochigi
# https://maps.googleapis.com/maps/api/staticmap?center=36.8066862,139.924054&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_
zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 0_Buzen_Fukuoka
# https://maps.googleapis.com/maps/api/staticmap?center=33.6115108,131.130051&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 1_Sendai_Miyagi
# https://maps.googleapis.com/maps/api/staticmap?center=38.268215,140.8693558&zoom=16&size=640x640&maptype=satellite&key=AIzaSyBG0yssmOa53O3uJf8HDD0ikoD3SioeD5M
# 731 images are stored at ../imgs/

# %%
def load_image(img_dir='../imgs/'):
    """
    Load image and label data
    @ param img_dir: directory pass for image folder
    @ return img_l: numpay array of image
    @ return lbl_l: numpay array of label
    """
    img_names = os.listdir(img_dir)
    X = []
    Y = []
    for img_name in img_names:
        if img_name[0] == '0' or img_name[0] == '1':
            lbl = int(img_name[0])
            Y.append(lbl)
            img = cv2.imread(str(img_dir + img_name))
            b,g,r = cv2.split(img)
            img = cv2.merge([r,g,b])
            X.append(img/256)
            print(img_name)
        
    X = np.array(X)
    Y = np.array(Y)
    np.savez("hoge", x=X, y=Y)

# %%
load_image()
# Out:
# 0_Kasaoka_Okayama.jpg
# 0_Honcho_Chiba.jpg
# 0_Ikedacho_Tokushima.jpg
# 0_Katori-shi_Chiba.jpg
# 0_Tarumizu_Kagoshima.jpg
# 1_Kitakyushu_Fukuoka.jpg
# 0_Koshigaya_Saitama.jpg
# 0_Gamagori_Aichi.jpg
# 0_Ayabe_Kyoto.jpg
# 0_Asaka_Saitama.jpg
# 0_Sakaidecho_Kagawa.jpg
# 0_Hanno_Saitama.jpg
# 0_Kamogawa_Chiba.jpg
# 0_Inawashiro_Fukushima.jpg
# 0_Tarui_Gifu.jpg
# 0_Rumoi_Hokkaido.jpg
# 0_Himimachi_Toyama.jpg
# 0_Bihoro_Hokkaido.jpg
# 0_Sagae_Yamagata.jpg
# 0_Daitocho_osaka.jpg
# 1_Sendai_Miyagi.jpg
# 0_okawara_Miyagi.jpg
# 0_Kukichuo_Saitama.jpg
# 0_Funehikimachi-funehiki_Fukushima.jpg
# 0_Hachioji_Tokyo.jpg
# 0_Urayasu_Tokyo.jpg
# 0_Tanuma_Tochigi.jpg
# 0_Atami_Shizuoka.jpg
# 0_Nakamura_Kochi.jpg
# 0_otsuchi_Iwate.jpg
# 0_Fujioka_Gunma.jpg
# 0_Maki_Niigata.jpg
# 0_Yamada_Iwate.jpg
# 0_Takaishi_osaka.jpg
# 0_Gujo_Gifu.jpg
# 0_Shido_Kagawa.jpg
# 0_Kameoka_Kyoto.jpg
# 0_Oita_Oita.jpg
# 0_Okazaki_Aichi.jpg
# 0_Shinichi_Hiroshima.jpg
# 0_Kofu_Yamanashi.jpg
# 0_Kurihashi_Saitama.jpg
# 0_Gifu-shi_Gifu.jpg
# 0_Iida_Nagano.jpg
# 0_Takaoka_Toyama.jpg
# 0_Yanagawamachi-saiwaicho_Fukushima.jpg
# 0_Takahagi_Ibaraki.jpg
# 0_Matsudo_Chiba.jpg
# 0_Nakatsu_Fukuoka.jpg
# 0_Itako_Ibaraki.jpg
# 0_Shizukuishi_Iwate.jpg
# 0_Hojo_Ehime.jpg
# 0_Ono_Fukui.jpg
# 0_Kusatsu_Shiga.jpg
# 0_Sukumo_Kochi.jpg
# 0_Hikone_Shiga.jpg
# 0_Honjo_Saitama.jpg
# 0_Chino_Nagano.jpg
# 0_Tsukawaki_Oita.jpg
# 0_Takanabe_Miyazaki.jpg
# 0_Arai_Niigata.jpg
# 0_Hirado_Nagasaki.jpg
# 0_Miyoshi_Hiroshima.jpg
# 0_Usuki_Oita.jpg
# 0_Yaizu_Shizuoka.jpg
# 0_Ube_Yamaguchi.jpg
# 0_Komatsushimacho_Tokushima.jpg
# 0_Shinshiro_Aichi.jpg
# 0_Shibukawa_Gunma.jpg
# 0_Kawaguchi_Saitama.jpg
# 0_Kuroda_Aichi.jpg
# 0_Sakaiminato_Shimane.jpg
# 0_Muko_Kyoto.jpg
# 0_Shirone_Niigata.jpg
# 0_Yanagawa_Fukuoka.jpg
# 0_Mitake_Gifu.jpg
# 0_Atsugi_Kanagawa.jpg
# 0_Takanosu_Akita.jpg
# 0_Masuda_Shimane.jpg
# 0_Sugito_Saitama.jpg
# 0_Zama_Kanagawa.jpg
# 0_Nichinan_Miyazaki.jpg
# 0_Fuchucho_Hiroshima.jpg
# 0_Suibara_Niigata.jpg
# 0_Fukuyama_Hiroshima.jpg
# 0_Kameyama_Mie.jpg
# 0_Hobaramachi_Fukushima.jpg
# 0_Hanawa_Akita.jpg
# 0_Yoshikawa_Saitama.jpg
# 0_Hamada_Shimane.jpg
# 0_Katsuyama_Fukui.jpg
# 0_Ino_Kochi.jpg
# 0_Kozakai-cho_Aichi.jpg
# 0_Yonezawa_Yamagata.jpg
# 0_Ujiie_Tochigi.jpg
# 0_Gobo_Wakayama.jpg
# 0_Matsubase_Kumamoto.jpg
# 0_Namie_Fukushima.jpg
# 0_Kakuda_Miyagi.jpg
# 0_Chiryu_Aichi.jpg
# 0_Niimi_Okayama.jpg
# 0_Kaizuka_osaka.jpg
# 0_omiya_Ibaraki.jpg
# 0_Fukura_Hyogo.jpg
# 0_Yugawara_Kanagawa.jpg
# 0_Ushiku_Ibaraki.jpg
# 0_Karasuyama_Tochigi.jpg
# 0_Hita_Oita.jpg
# 0_Mooka_Tochigi.jpg
# 0_Daigo_Ibaraki.jpg
# 1_Chiba_Chiba.jpg
# 0_Funaishikawa_Ibaraki.jpg
# 0_Kamakura_Kanagawa.jpg
# 0_Kudamatsu_Yamaguchi.jpg
# 0_Tomiya_Miyagi.jpg
# 0_Tamana_Kumamoto.jpg
# 0_Zushi_Kanagawa.jpg
# 0_Chofugaoka_Tokyo.jpg

# %%
import traceback
classes = 2
data_size = 640 * 640 * 3
 
 
def model_training(x, y):
    model = Sequential()
    # 隠れ層:64、入力層:データサイズ、活性化関数:Relu
    model.add(Dense(units=64, activation='relu', input_dim=(data_size)))
    # 出力層:分類するクラス数、活性化関数:Softmax
    model.add(Dense(units=classes, activation='softmax'))
    # モデルをコンパイル
    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='sgd',
                  metrics=['accuracy'])
    model.fit(x, y, epochs=60)
    return model
 
 
def model_evaluation(model, x_test, y_test):
    score = model.evaluate(x_test, y_test)
    print(score)
    print('Loss = ', score[0])
    print('Accuracy = ', score[1])
 
 
if __name__ == '__main__':
 
    try:
        # データの読み込み
        data_set = np.load('./hoge.npz')
        X = data_set["x"]
        Y = data_set["y"]
        # 2次元に変換
        X = np.reshape(X, (-1, data_size))
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8)
        model = model_training(X_train, Y_train)
        model_evaluation(model, X_test, Y_test)
    except Exception as e:
        traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-43-cf6828b709e8>", line 37, in <module>
#     model = model_training(X_train, Y_train)
#   File "<ipython-input-43-cf6828b709e8>", line 9, in model_training
#     model.add(Dense(units=64, activation='relu', input_dim=(data_size)))
# TypeError: __init__() missing 1 required positional argument: 'output_dim'

# %%
data_set = np.load('hoge.npz')
X = data_set["x"]
Y = data_set["y"]
# 2次元に変換
#X = np.reshape(X, (-1, data_size))

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D, AveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler, ReduceLROnPlateau
from keras.optimizers import SGD
from keras.regularizers import l2
import matplotlib.image as mpimg
from scipy.misc import imresize
import numpy as np
import keras.backend as K
import math
import os
from sklearn.model_selection import train_test_split

# %%
K.clear_session()
img_size=640
# Data Augumentation
# Parameter Reference: http://aidiary.hatenablog.com/entry/20161212/1481549365
train_datagen = ImageDataGenerator(
        rescale = 1.0/255
        horizontal_flip=True,
        vertical_flip=True)

test_datagen = ImageDataGenerator(rescale = 1.0/255)

#画像の読み込み
def load_images(img_dir='../imgs/'):
    all_imgs = []
    all_classes = []
    
    img_names = os.listdir(img_dir)    
    for img_name in img_names:
        if img_name[0] == '0' or img_name[0] == '1':
            lbl = int(img_name[0])
            all_classes.append(lbl)
            img_arr = mpimg.imread(str(img_dir + img_name))
            resize_img_ar = imresize(img_arr, (img_size, img_size))
            all_imgs.append(resize_img_ar)
            
    return np.array(all_imgs), np.array(all_classes)

X, Y = load_images('../imgs/')
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.8)
train_generator = train_datagen.flow(X_train, y_train, batch_size=64, seed = 13)
test_generator = test_datagen.flow(X_test, y_test, batch_size=64, seed = 13)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
#Inception v3モデルの読み込み。最終層は読み込まない
base_model = InceptionV3(weights='imagenet', include_top=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in concatenate(tensors, axis)
#    1424         try:
# -> 1425             return tf.concat_v2([to_dense(x) for x in tensors], axis)
#    1426         except AttributeError:
#
# AttributeError: module 'tensorflow' has no attribute 'concat_v2'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-a3f9a0e91d20> in <module>()
#       1 #Inception v3モデルの読み込み。最終層は読み込まない
# ----> 2 base_model = InceptionV3(weights='imagenet', include_top=False)
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/applications/inception_v3.py in InceptionV3(include_top, weights, input_tensor, input_shape, classes)
#     153         x = merge([branch1x1, branch5x5, branch3x3dbl, branch_pool],
#     154                   mode='concat', concat_axis=channel_axis,
# --> 155                   name='mixed' + str(i))
#     156
#     157     # mixed 3: 17 x 17 x 768
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/engine/topology.py in merge(inputs, mode, concat_axis, dot_axes, output_shape, output_mask, arguments, name)
#    1678                             node_indices=node_indices,
#    1679                             tensor_indices=tensor_indices,
# -> 1680                             name=name)
#    1681         return merge_layer.inbound_nodes[0].output_tensors[0]
#    1682     else:
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/engine/topology.py in __init__(self, layers, mode, concat_axis, dot_axes, output_shape, output_mask, arguments, node_indices, tensor_indices, name)
#    1299                                        node_indices, tensor_indices)
#    1300             self.built = True
# -> 1301             self.add_inbound_node(layers, node_indices, tensor_indices)
#    1302         else:
#    1303             self.built = False
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/engine/topology.py in add_inbound_node(self, inbound_layers, node_indices, tensor_indices)
#     633         # creating the node automatically updates self.inbound_nodes
#     634         # as well as outbound_nodes on inbound layers.
# --> 635         Node.create_node(self, inbound_layers, node_indices, tensor_indices)
#     636
#     637     def get_output_shape_for(self, input_shape):
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/engine/topology.py in create_node(cls, outbound_layer, inbound_layers, node_indices, tensor_indices)
#     170             output_shapes = to_list(outbound_layer.get_output_shape_for(input_shapes[0]))
#     171         else:
# --> 172             output_tensors = to_list(outbound_layer.call(input_tensors, mask=input_masks))
#     173             output_masks = to_list(outbound_layer.compute_mask(input_tensors, input_masks))
#     174             output_shapes = to_list(outbound_layer.get_output_shape_for(input_shapes))
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/engine/topology.py in call(self, inputs, mask)
#    1392
#    1393         elif self.mode == 'concat':
# -> 1394             return K.concatenate(inputs, axis=self.concat_axis)
#    1395
#    1396         elif self.mode == 'mul':
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in concatenate(tensors, axis)
#    1425             return tf.concat_v2([to_dense(x) for x in tensors], axis)
#    1426         except AttributeError:
# -> 1427             return tf.concat(axis, [to_dense(x) for x in tensors])
#    1428
#    1429
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/tensorflow/python/ops/array_ops.py in concat(values, axis, name)
#    1059       ops.convert_to_tensor(axis,
#    1060                             name="concat_dim",
# -> 1061                             dtype=dtypes.int32).get_shape(
#    1062                             ).assert_is_compatible_with(tensor_shape.scalar())
#    1063       return identity(values[0], name=scope)
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, preferred_dtype)
#     609       name=name,
#     610       preferred_dtype=preferred_dtype,
# --> 611       as_ref=False)
#     612
#     613
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype)
#     674
#     675         if ret is None:
# --> 676           ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     677
#     678         if ret is NotImplemented:
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     119                                          as_ref=False):
#     120   _ = as_ref
# --> 121   return constant(v, dtype=dtype, name=name)
#     122
#     123
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     100   tensor_value = attr_value_pb2.AttrValue()
#     101   tensor_value.tensor.CopyFrom(
# --> 102       tensor_util.make_tensor_proto(value, dtype=dtype, shape=shape, verify_shape=verify_shape))
#     103   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     104   const_tensor = g.create_op(
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/tensorflow/python/framework/tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     374       nparray = np.empty(shape, dtype=np_dt)
#     375     else:
# --> 376       _AssertCompatible(values, dtype)
#     377       nparray = np.array(values, dtype=np_dt)
#     378       # check to them.
#
# /Users/isaac/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/tensorflow/python/framework/tensor_util.py in _AssertCompatible(values, dtype)
#     300     else:
#     301       raise TypeError("Expected %s, got %s of type '%s' instead." %
# --> 302                       (dtype.name, repr(mismatch), type(mismatch).__name__))
#     303
#     304
#
# TypeError: Expected int32, got list containing Tensors of type '_Message' instead.

# %%
#最終層の設定
x = base_model.output
x = GlobalAveragePooling2D()(x)
predictions = Dense(1, kernel_initializer="glorot_uniform", activation="sigmoid", kernel_regularizer=l2(.0005))(x)

model = Model(inputs=base_model.input, outputs=predictions)

#base_modelはweightsを更新しない
for layer in base_model.layers:
    layer.trainable = False

opt = SGD(lr=.01, momentum=.9)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.hdf5', verbose=1, save_best_only=True)
csv_logger = CSVLogger('model.log')

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.001)

history = model.fit_generator(train_generator,
                    steps_per_epoch=2000,
                    epochs=10,
                    validation_data=test_generator,
                    validation_steps=800,
                    verbose=1,
                    callbacks=[reduce_lr, csv_logger, checkpointer])
